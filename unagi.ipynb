# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import os
import sys

import galsim
import numpy as np

import astropy.units as u
from astropy import wcs 
from astropy.io import fits
from astropy.coordinates import SkyCoord
from astropy.visualization import make_lupton_rgb
from astropy.utils.data import download_file, clear_download_cache

import matplotlib as plt

# %%
from unagi import hsc 
from unagi import task
from unagi import query
from unagi import config 
from unagi import catalog 
from unagi import plotting

# %%
pdr2 = hsc.Hsc(dr='pdr2', rerun = 'pdr2_wide')
# Out:
# # Get table list from /usr/local/lib/python3.6/dist-packages/unagi-0.1.3.dev9-py3.6.egg/unagi/data/pdr2_wide/pdr2_wide_tables.fits

# %%
#pdr2 = hsc.Hsc(dr='dr3', rerun = 's20a_wide')
# for the above to work, need an account for the non-public data releases!

# %% [markdown]
# # Connecting the image with HSC photometric measurements

# %%
coord_1 = SkyCoord(138.808426, 3.703354, frame='icrs', unit='deg')
coord_1 = SkyCoord(150.0913, 2.205916, frame='icrs', unit='deg')

# Physical size
s_phy = 100.0 * u.kpc

redshift = 0.20

# %% [markdown]
# ### Get the i-band cutout image

# %%
cutout = task.hsc_cutout(
    coord_1, cutout_size = s_phy, redshift = redshift, filters = 'i', 
    archive = pdr2, use_saved = False, verbose = True, 
    save_output = False)
# Out:
# # Retrieving cutout image in filter: i
# # Invalid id or password!
# # Invalid id or password!
# # Invalid id or password!
# # Invalid id or password!
# # Invalid id or password!
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/unagi-0.1.3.dev9-py3.6.egg/unagi/hsc.py in _request(self, url)
#     237         try:
# --> 238             result = urllib.request.urlopen(url)
#     239             return result
#
# /usr/lib/python3.6/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#
# /usr/lib/python3.6/urllib/request.py in open(self, fullurl, data, timeout)
#     531             meth = getattr(processor, meth_name)
# --> 532             response = meth(req, response)
#     533
#
# /usr/lib/python3.6/urllib/request.py in http_response(self, request, response)
#     641             response = self.parent.error(
# --> 642                 'http', request, response, code, msg, hdrs)
#     643
#
# /usr/lib/python3.6/urllib/request.py in error(self, proto, *args)
#     569             args = (dict, 'default', 'http_error_default') + orig_args
# --> 570             return self._call_chain(*args)
#     571
#
# /usr/lib/python3.6/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#
# /usr/lib/python3.6/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     649     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 650         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     651
#
# HTTPError: HTTP Error 401: Unauthorized
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/tenacity/__init__.py in __call__(self, fn, *args, **kwargs)
#     425                 try:
# --> 426                     result = fn(*args, **kwargs)
#     427                 except BaseException:
#
# /usr/local/lib/python3.6/dist-packages/unagi-0.1.3.dev9-py3.6.egg/unagi/hsc.py in _request(self, url)
#     248                 print("# Error message: {}".format(e))
# --> 249             raise Exception("# Can not download: {}".format(url))
#     250
#
# Exception: # Can not download: https://hsc-release.mtk.nao.ac.jp/das_cutout/pdr2/cgi-bin/cutout?ra=150.091&dec=2.20592&sw=30.306199arcsec&sh=30.306199arcsec&type=coadd&image=on&mask=off&variance=off&filter=HSC-I&rerun=pdr2_wide
#
# The above exception was the direct cause of the following exception:
#
# RetryError                                Traceback (most recent call last)
# <ipython-input-6-dd25a89428e1> in <module>
#       2     coord_1, cutout_size = s_phy, redshift = redshift, filters = 'i',
#       3     archive = pdr2, use_saved = False, verbose = True,
# ----> 4     save_output = False)
#
# /usr/local/lib/python3.6/dist-packages/unagi-0.1.3.dev9-py3.6.egg/unagi/task.py in hsc_cutout(coord, coord_2, cutout_size, filters, dr, rerun, redshift, cosmo, img_type, prefix, verbose, archive, save_output, use_saved, output_dir, **kwargs)
#     255             cutout_hdu = archive.get_cutout_image(
#     256                 coord, coord_2=coord_2, w_half=ang_size_w, h_half=ang_size_h,
# --> 257                 filt=filt, img_type=img_type, **kwargs)
#     258
#     259             if img_type == 'coadd' and save_output:
#
# /usr/local/lib/python3.6/dist-packages/unagi-0.1.3.dev9-py3.6.egg/unagi/hsc.py in get_cutout_image(self, coord, coord_2, w_half, h_half, filt, img_type, image, variance, mask, verbose)
#     271             print("# Downloading FITS image from {}".format(cutout_url))
#     272         # TODO: Not sure this is the best way though
# --> 273         cutout = fits.open(self._request(cutout_url))
#     274
#     275         return cutout
#
# ~/.local/lib/python3.6/site-packages/tenacity/__init__.py in wrapped_f(*args, **kw)
#     331         @_utils.wraps(f)
#     332         def wrapped_f(*args, **kw):
# --> 333             return self(f, *args, **kw)
#     334
#     335         def retry_with(*args, **kwargs):
#
# ~/.local/lib/python3.6/site-packages/tenacity/__init__.py in __call__(self, fn, *args, **kwargs)
#     421             retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     422         while True:
# --> 423             do = self.iter(retry_state=retry_state)
#     424             if isinstance(do, DoAttempt):
#     425                 try:
#
# ~/.local/lib/python3.6/site-packages/tenacity/__init__.py in iter(self, retry_state)
#     371             if self.reraise:
#     372                 raise retry_exc.reraise()
# --> 373             six.raise_from(retry_exc, fut.exception())
#     374
#     375         if self.wait:
#
# ~/.local/lib/python3.6/site-packages/six.py in raise_from(value, from_value)
#
# RetryError: RetryError[<Future at 0x7f534c0affd0 state=finished raised Exception>]
